# %%
# IMPORT PANDAS LIBRARY
# IMPORT AND READ DATA FILE

import pandas as pd
Data = pd.read_excel(r'/content/HR analytics.xlsx')
Data

# TO READ HEAD AND TAIL DATA

Head = Data.head()
Head

Tail = Data.tail()
Tail

# %%
# TO SHOE COUNT OF NAN VALUES

import pandas as pd
Data = pd.read_excel(r'/content/HR analytics.xlsx')
DF= pd.DataFrame(Data)
DF= pd.DataFrame(Data)
Nan_values = DF.isna()
Count = Nan_values.sum()
Count

# %%
# TO FILL '0' INSTEAD OF NAN VALUES IN 'previous_year_rating' COLUMN

import pandas as pd
Data = pd.read_excel(r'/content/HR analytics.xlsx')
DF= pd.DataFrame(Data)
Fill = DF['previous_year_rating'].fillna(0)
Fill

# %%
# TO SHOW HOW MANY DEPARTMENTS

import pandas as pd
Data = pd.read_excel(r'/content/HR analytics.xlsx')
DF= pd.DataFrame(Data)
unique_departments = DF['department'].unique()
unique_departments
num_departments = len(unique_departments)
num_departments

# TO REMOVE UNUSED COLUMNS
Column_remove = DF.drop(['region'],axis=1)
Column_remove

# %%
# TO REMOVE DUPLLICATES

import pandas as pd
Data = pd.read_excel(r'/content/HR analytics.xlsx')
DF= pd.DataFrame(Data)
Clean_Data = DF.drop_duplicates()
Clean_Data

# %%
# TO SORT THE SPECIFIC COLUMNS IN ASCENDING ORDER
import pandas as pd
Data = pd.read_excel(r'/content/HR analytics.xlsx')
DF= pd.DataFrame(Data)
Sort_column = DF.sort_values(by='length_of_service',ascending=True,inplace=True)
DF
